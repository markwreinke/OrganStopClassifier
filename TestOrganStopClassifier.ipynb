# %% [markdown]
# <a href="https://colab.research.google.com/github/markwreinke/OrganStopClassifier/blob/main/TestOrganStopClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Start with the imports
import pandas as pd
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm_notebook as tqdm
import os
import pickle
import IPython

# %%
# Mount GoogleDrive, cd and confirm current directory
from google.colab import drive
drive.mount("/content/drive")

dir = "/content/drive/My Drive/OrganStopDataset"
print(os.getcwd())

if(os.getcwd() != dir):
  os.chdir(dir)

print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/OrganStopDataset
# /content/drive/My Drive/OrganStopDataset

# %%
# Here we are going to convert a Spectrogram into an image
def spec_to_image(spec, eps=1e-6):
  mean = spec.mean()
  std = spec.std()
  spec_norm = (spec - mean) / (std + eps)
  spec_min, spec_max = spec_norm.min(), spec_norm.max()
  spec_scaled = 255 * (spec_norm - spec_min) / (spec_max - spec_min)
  spec_scaled = spec_scaled.astype(np.uint8)
  return spec_scaled

  # This spectrogram is normalized using z score normalization and 
  # scaled using min-max scaling so its values lie between 0 and 255

# %%
# This function give a mel spectrogram of the given file
#  sr=None -> Librosa should use the native sampling rate of 44.1KHz to load the audio data instead of the default of 22.05KHz
#  Next the first 1 seconds of given audio is extracted
#  2048 samples are chosen for each window (about 46ms)
#  A hop_length of 512 samples is chose, meaning the window is moved by skipping 512 samples to get the next time frame
#  The number of mel filters is 128, makes the height of the spectrogram image 128
#  fmin and fmax are the lowest and highest frequencies
def get_melspectrogram_db(file_path, sr=None, n_fft=2048, hop_length=512, n_mels=128, fmin=20, fmax=8300, top_db=80):
  wav, sr = librosa.load(file_path, sr=sr)
  if wav.shape[0]<5*sr:
     wav=np.pad(wav,int(np.ceil((5*sr-wav.shape[0])/2)),mode='reflect')
  else:
    wav=wav[:5*sr]

  spec=librosa.feature.melspectrogram(wav, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels, fmin=fmin, fmax=fmax)

  #Librosa squares the magnitude of the spectrogram when constructing Mel Spectrogram, so we use power_to_db to convert power magnitude to decipels. top_db is used to threshold the output.
  spec_db=librosa.power_to_db(spec, top_db=top_db)
  return spec_db

# %%
# This is us loading data into pytorch by building dataloaders to
# preprocess and load data.

class OrganStopSamples(Dataset):
  def __init__(self, base, df, in_col, out_col):
    self.df = df
    self.data = []
    self.labels = []
    self.c2i = {}
    self.i2c = {}
    self.categories = sorted(df[out_col].unique())
    for i, category in enumerate(self.categories):
      self.c2i[category] = i
      self.i2c[i] = category
    for ind in tqdm(range(len(df))):
      row = df.iloc[ind]
      file_path = os.path.join(base, row[in_col])
      # print("base: ", base, "\nin_col: ", in_col, "\nrow[in_col]: ", row[in_col], "\nfile_path:", file_path)
      self.data.append(spec_to_image(get_melspectrogram_db(file_path))[np.newaxis,...])
      self.labels.append(self.c2i[row['category_1']])

  def __len__(self):
     return len(self.data)
  def __getitem__(self, idx):
    return self.data[idx], self.labels[idx]

# %%
# This is its own model, not the resnet34
class OrganStopModel(nn.Module):
  def __init__(self, input_shape, batch_size=16, num_cats=50):
    super().__init__()
    self.conv1 = nn.Conv2d(1, 32, kernel_size = 3, stride=1, padding=1)
    self.bn1 = nn.BatchNorm2d(32)
    self.conv2 = nn.Conv2d(32, 32, kernel_size = 3, stride=1, padding=1)
    self.bn2 = nn.BatchNorm2d(32)
    self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
    self.bn3 = nn.BatchNorm2d(64)
    self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
    self.bn4 = nn.BatchNorm2d(64)
    self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
    self.bn5 = nn.BatchNorm2d(128)
    self.conv6 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
    self.bn6 = nn.BatchNorm2d(128)
    self.conv7 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
    self.bn7 = nn.BatchNorm2d(256)
    self.conv8 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
    self.bn8 = nn.BatchNorm2d(256)
    self.dense1 = nn.Linear(256*(((input_shape[1]//2)//2)//2)*(((input_shape[2]//2)//2)//2),500)
    self.dropout = nn.Dropout(0.5)
    self.dense2 = nn.Linear(500, num_cats)
  def forward(self, x):
    x = self.conv1(x)
    x = F.relu(self.bn1(x))
    x = self.conv2(x)
    x = F.relu(self.bn2(x))
    x = F.max_pool2d(x, kernel_size=2) 
    x = self.conv3(x)
    x = F.relu(self.bn3(x))
    x = self.conv4(x)
    x = F.relu(self.bn4(x))
    x = F.max_pool2d(x, kernel_size=2)
    x = self.conv5(x)
    x = F.relu(self.bn5(x))
    x = self.conv6(x)
    x = F.relu(self.bn6(x))
    x = F.max_pool2d(x, kernel_size=2)
    x = self.conv7(x)
    x = F.relu(self.bn7(x))
    x = self.conv8(x)
    x = F.relu(self.bn8(x))
    x = x.view(x.size(0),-1)
    x = F.relu(self.dense1(x))
    x = self.dropout(x)
    x = self.dense2(x)
    return x

# %%
if torch.cuda.is_available():
  device=torch.device('cuda:0')
else:
  device=torch.device('cpu')

# %%
# This loads up the saved model (that was already trained)
with open('organStopModel.pth', 'rb') as modelF:
  trained_model = torch.load(modelF, map_location = device)
modelF.close()

#This is important to call to set dropout and batch normalization layers to evaluation mode
trained_model.eval()
# Out:
# OrganStopModel(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dense1): Linear(in_features=217088, out_features=500, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (dense2): Linear(in_features=500, out_features=3, bias=True)
# )

# %%
testDataFrame = pd.read_csv('stopTestDirectory.csv')
testDataFrame.head()
directory = "/content/drive/My Drive/OrganStopDataset/TestData"
test = testDataFrame[testDataFrame['fold']!=6]

print(type(test))

testData = OrganStopSamples('TestData', test, 'filename', 'category_1')
testLoader = DataLoader(testData, batch_size = 16, shuffle = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=417.0), HTML(value='')))

# %%
# Save the testdata dataloader as a file
with open('organTestData.pkl', 'wb') as testDataF:
  pickle.dump(testData.i2c, testDataF)

testDataF.close()

# %%
with open('organTestData.pkl', 'rb') as openTestF:
  testDataFile = pickle.load(openTestF)
openTestF.close()

# %%
filenameTest = os.getcwd() + "/TestData/Trumpette8AT4051 AT AT4051 WinnRight-103.wav"
print(os.getcwd())
spec = spec_to_image(get_melspectrogram_db(filenameTest))
spec_t == torch.tensor(spec).to(device, dtype = torch.float32)
pr = trained_model(spec_t.reshape(1,1,*spec_t.shape))
ind = pr.argmax(dim=1).cpu().detach().numpy().ravel()[0]
print("ind: " + str(ind))
print(testDataFile)
print(testDataFile[ind])
IPython.display.display(IPython.display.Audio(filename= filenameTest))
# Out:
# /content/drive/My Drive/OrganStopDataset
# ind: 0
# {0: 'Krummhorn8', 1: 'Principal8', 2: 'Trumpette8'}
# Krummhorn8
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dataiter4 = iter(testLoader)
samples, labels = dataiter4.next()

#IPython.display.display(IPython.display.Audio(filename = directory + "/" + sample))

print(labels)
# Out:
# tensor([2, 1, 0, 1, 1, 3, 2, 1, 1, 1, 2, 1, 1, 2, 2, 1])

# %%
i = 0

with open('organTestData.pkl', 'rb') as openTestF:
  testDataFile = pickle.load(openTestF)
openTestF.close()

mislabeledSamples = []
mislabeledLabel = []
correctLabel = []
mislabeledFilename = []


for sampleFile in os.scandir(directory):
  filename = sampleFile.name
  spec = spec_to_image(get_melspectrogram_db(sampleFile))
  spec_t = torch.tensor(spec).to(device, dtype = torch.float32)

  pr = trained_model.forward(spec_t.reshape(1, 1, *spec_t.shape))
  ind = pr.argmax(dim = 1).cpu().detach().numpy().ravel()[0]

  print("i = " + str(i) + " ind = " + str(ind))
  print("Estimated: " + str(testDataFile[ind]) + " Actual: " + str(testDataFrame.at[i, "category_1"]))
  print("Filname: " + str(filename))
  if str(testDataFile[ind]) != str(testDataFrame.at[i, "category_1"]):
    mislabeledSamples.append(filename)
    mislabeledLabel.append(str(testDataFrame.at[i, "category_1"]))
    correctLabel.append(str(testDataFile[ind]))
    mislabeledFilename.append(filename)
  i += 1
# Out:
# i = 0 ind = 0
# Estimated: Earthworks Actual: Krummhorn8
# Filname: Krummhorn8AT4051Left-Live10 AT4051 Left-109.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-34a46145ccde> in <module>()
#      16   spec_t = torch.tensor(spec).to(device, dtype = torch.float32)
#      17
# ---> 18   pr = trained_model.forward(spec_t.reshape(1, 1, *spec_t.shape))
#      19   ind = pr.argmax(dim = 1).cpu().detach().numpy().ravel()[0]
#      20
#
# <ipython-input-7-2d7437647bec> in forward(self, x)
#      32     x = self.conv4(x)
#      33     x = F.relu(self.bn4(x))
# ---> 34     x = F.max_pool2d(x, kernel_size=2)
#      35     x = self.conv5(x)
#      36     x = F.relu(self.bn5(x))
#
# /usr/local/lib/python3.6/dist-packages/torch/_jit_internal.py in fn(*args, **kwargs)
#     265             return if_true(*args, **kwargs)
#     266         else:
# --> 267             return if_false(*args, **kwargs)
#     268
#     269     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     584         stride = torch.jit.annotate(List[int], [])
#     585     return torch.max_pool2d(
# --> 586         input, kernel_size, stride, padding, dilation, ceil_mode)
#     587
#     588 max_pool2d = boolean_dispatch(
#
# KeyboardInterrupt:

# %%
print("mislabeledLabel: " + str(len(mislabeledLabel)))
print("correctLabel: " + str(len(correctLabel)))
print("mislabeledSamples: " + str(len(mislabeledSamples)))
print("mislabeledFilename: " + str(len(mislabeledFilename)))
print(mislabeledLabel)
j = 0
# This appears to be malfunctioning?
for sample in mislabeledSamples:
  print("The mislabeled sample was labeled " + mislabeledLabel[j])
  print("It was supposed to be a " + correctLabel[j])
  print("Here is the filename: " + mislabeledFilename[j])
  IPython.display.display(IPython.display.Audio(filename = directory + "/" + sample))
  j =+ 1
