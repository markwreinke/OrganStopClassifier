# %% [markdown]
# <a href="https://colab.research.google.com/github/markwreinke/OrganStopClassifier/blob/main/TestOrganStopClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Start with the imports
import pandas as pd
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm_notebook as tqdm
import os
import pickle
import IPython

# %%
# Mount GoogleDrive, cd and confirm current directory
from google.colab import drive
drive.mount("/content/drive")

dir = "/content/drive/My Drive/OrganStopDataset"
print(os.getcwd())

if(os.getcwd() != dir):
  os.chdir(dir)

print(os.getcwd())
# Out:
# Mounted at /content/drive
# /content
# /content/drive/My Drive/OrganStopDataset

# %%
# Here we are going to convert a Spectrogram into an image
def spec_to_image(spec, eps=1e-6):
  mean = spec.mean()
  std = spec.std()
  spec_norm = (spec - mean) / (std + eps)
  spec_min, spec_max = spec_norm.min(), spec_norm.max()
  spec_scaled = 255 * (spec_norm - spec_min) / (spec_max - spec_min)
  spec_scaled = spec_scaled.astype(np.uint8)
  return spec_scaled

  # This spectrogram is normalized using z score normalization and 
  # scaled using min-max scaling so its values lie between 0 and 255

# %%
# This function give a mel spectrogram of the given file
#  sr=None -> Librosa should use the native sampling rate of 44.1KHz to load the audio data instead of the default of 22.05KHz

#  Next if the sample is less than num_sec long, it is padded with refected versions of itself - i.e., if num_sec is 5,and a 1 second clip is sent it, it will be changed to: clip + reversed clip + clip + reversed clip + clip.
# If the clip runtime is greater than num_sec, it will be truncated.

#  2048 samples are chosen for each window (about 46ms)
#  A hop_length of 512 samples is chose, meaning the window is moved by skipping 512 samples to get the next time frame
#  The number of mel filters is 128, makes the height of the spectrogram image 128
#  fmin and fmax are the lowest and highest frequencies
def get_melspectrogram_db(file_path, sr=None, n_fft=2048, hop_length=512, n_mels=128, fmin=20, fmax=8300, top_db=80, num_sec = 1):
  wav, sr = librosa.load(file_path, sr=sr)
  if wav.shape[0]<num_sec*sr:
     wav=np.pad(wav,int(np.ceil((num_sec*sr-wav.shape[0])/2)),mode='reflect')
  else:
    wav=wav[:num_sec*sr]

  spec=librosa.feature.melspectrogram(wav, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels, fmin=fmin, fmax=fmax)

  #Librosa squares the magnitude of the spectrogram when constructing Mel Spectrogram, so we use power_to_db to convert power magnitude to decipels. top_db is used to threshold the output.
  spec_db=librosa.power_to_db(spec, top_db=top_db)
  return spec_db

# %%
# This is us loading data into pytorch by building dataloaders to
# preprocess and load data.
# I augmented it by getting it to save the filename as well

# Where Torch Dataloaders support Map-Style and Iterable-Style datasets, this one is a Map-style dataset as it implements __getitem__() and __len__() protocals, and s represents a mapp from indeices/keys to data samples.


class OrganStopSamples(Dataset):
  def __init__(self, base, df, in_col, out_col):
    self.df = df
    self.data = []
    self.labels = []
    self.filenames = []
    self.c2i = {} # This is a dictionary that maps Category:index
    self.i2c = {} # This is a dicitonary that maps index: category
    self.categories = sorted(df[out_col].unique())
    for i, category in enumerate(self.categories):
      self.c2i[category] = i
      self.i2c[i] = category
    for ind in tqdm(range(len(df))):
      row = df.iloc[ind]
      file_path = os.path.join(base, row[in_col])
      # print("base: ", base, "\nin_col: ", in_col, "\nrow[in_col]: ", row[in_col], "\nfile_path:", file_path)
      self.data.append(spec_to_image(get_melspectrogram_db(file_path))[np.newaxis,...]) # This takes the mel_spectrogram of the current file and appends it to the data list, also adds a new dimension to the front of the data
      self.labels.append(self.c2i[row['category_1']]) # This is the sister list of the data list, in which it maps the category to the data of the corresponding index of the data list.
      self.filenames.append(file_path) #Sace the filename

  def __len__(self):
     return len(self.data)
  def __getitem__(self, idx):
    return self.data[idx], self.labels[idx]
  def __getFileName__(self, idx):
    return self.filenames[idx]

# %%
# This is pretty close to the ESC50 project's module, with the change being the number of categoriesbeing 3 and not 50

class OrganStopModel(nn.Module):
  def __init__(self, input_shape, batch_size=16, num_cats=4):
    super().__init__()
    self.conv1 = nn.Conv2d(1, 32, kernel_size = 3, stride=1, padding=1)
    self.bn1 = nn.BatchNorm2d(32)
    self.conv2 = nn.Conv2d(32, 32, kernel_size = 3, stride=1, padding=1)
    self.bn2 = nn.BatchNorm2d(32)
    self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
    self.bn3 = nn.BatchNorm2d(64)
    self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
    self.bn4 = nn.BatchNorm2d(64)
    self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
    self.bn5 = nn.BatchNorm2d(128)
    self.conv6 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
    self.bn6 = nn.BatchNorm2d(128)
    self.conv7 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
    self.bn7 = nn.BatchNorm2d(256)
    self.conv8 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
    self.bn8 = nn.BatchNorm2d(256)
    self.dense1 = nn.Linear(256*(((input_shape[1]//2)//2)//2)*(((input_shape[2]//2)//2)//2),500)
    self.dropout = nn.Dropout(0.5)
    self.dense2 = nn.Linear(500, num_cats)
  def forward(self, x):
    x = self.conv1(x)
    x = F.relu(self.bn1(x))
    x = self.conv2(x)
    x = F.relu(self.bn2(x))
    x = F.max_pool2d(x, kernel_size=2) 
    x = self.conv3(x)
    x = F.relu(self.bn3(x))
    x = self.conv4(x)
    x = F.relu(self.bn4(x))
    x = F.max_pool2d(x, kernel_size=2)
    x = self.conv5(x)
    x = F.relu(self.bn5(x))
    x = self.conv6(x)
    x = F.relu(self.bn6(x))
    x = F.max_pool2d(x, kernel_size=2)
    x = self.conv7(x)
    x = F.relu(self.bn7(x))
    x = self.conv8(x)
    x = F.relu(self.bn8(x))
    x = x.view(x.size(0),-1)
    x = F.relu(self.dense1(x))
    x = self.dropout(x)
    x = self.dense2(x)
    return x

# %%
if torch.cuda.is_available():
  device=torch.device('cuda:0')
else:
  device=torch.device('cpu')

# %%
# This loads up the saved model (that was already trained)
with open('organStopModel.pth', 'rb') as modelF:
  trained_model = torch.load(modelF, map_location = device)
modelF.close()

#This is important to call to set dropout and batch normalization layers to evaluation mode
trained_model.eval()
# Out:
# OrganStopModel(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dense1): Linear(in_features=40960, out_features=500, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (dense2): Linear(in_features=500, out_features=4, bias=True)
# )

# %%
testDataFrame = pd.read_csv('stopTestDirectory.csv')
testDataFrame.head()
directory = "/content/drive/My Drive/OrganStopDataset/TestData"
test = testDataFrame[testDataFrame['fold']!=6]

print(type(test))

testData = OrganStopSamples('TestData', test, 'filename', 'category_1')
testLoader = DataLoader(testData, batch_size = 16, shuffle = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=599.0), HTML(value='')))

# %%
# Save the testdata's index:category attribute as a file
with open('organTestI2C.pkl', 'wb') as testDataF:
  pickle.dump(testData.i2c, testDataF)

# %%
with open('organTestI2C.pkl', 'rb') as openTestF:
  testDataI2C = pickle.load(openTestF)

# %%
mislabeledSamples = []

for i in range(0, testData.__len__()):
  data, label = testData.__getitem__(i)
  print("This clip should be a: " + str(testDataI2C[label]))
  spec_t = torch.tensor(data).to(device, dtype = torch.float32)
  pr = trained_model(spec_t.reshape(1,*spec_t.shape))
  ind = pr.argmax(dim=1).cpu().detach().numpy().ravel()[0]
  print("The model says it is a: " + str(testDataI2C[ind]))
  print("The model filename is: " + str(testData.__getFileName__(i)))
  print("")

  if str(testDataI2C[label]) != str(testDataI2C[ind]):
    mislabeledSamples.append((i, ind))
# Out:
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Left AT4051 WinLett-126.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8AT4051Right AT4051 WinnRight-126.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksLeft Earthworks, WinLEft-126.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8EarthworksRight Earthworks, WinRight-126.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8Octava Octava-126.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Left Shure KSM44 WinLeft-126.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-101.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-102.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-103.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-104.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-105.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-106.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-107.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-108.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-109.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-110.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-111.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-112.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-113.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-114.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-115.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-116.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-117.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-118.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-119.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-120.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-121.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-122.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-123.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-124.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-125.wav
#
# This clip should be a: Hautbois
# The model says it is a: Hautbois
# The model filename is: TestData/Hautbois8ShureKSM44Right ShureKSM44 WinRight-126.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-102.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-103.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-104.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-105.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-106.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-107.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-108.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-109.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-110.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-111.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-112.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-113.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-114.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-115.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-116.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-117.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-118.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-119.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-120.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-121.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-122.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-123.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Left-Live10 AT4051 Left-124.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-102.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-103.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-104.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-105.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-106.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-107.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-108.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-109.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-110.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-111.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-112.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-113.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-114.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-115.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-116.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-117.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-118.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-119.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-120.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-121.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-122.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8AT4051Right-Samples AT4051 Right-123.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-102.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-103.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-104.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-105.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-106.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-107.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-108.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-109.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-110.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-111.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-112.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-113.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-114.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-115.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-116.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-117.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-118.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-119.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-120.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-121.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-122.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-123.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksLeft EarthworksLeft-124.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-102.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-103.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-104.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-105.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-106.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-107.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-108.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-109.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-110.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-111.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-112.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-113.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-114.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-115.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-116.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-117.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-118.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-119.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-120.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-121.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-122.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-123.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8EarthworksRight-Live10 EarthworksRight-124.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-102.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-103.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-104.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-105.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-106.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-107.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-108.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-109.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-110.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-111.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-112.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-113.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-114.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-115.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-116.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-117.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-118.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-119.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-120.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8Octava-Live10 Octava-121.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-102.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-103.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-104.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-105.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-106.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-107.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-108.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-109.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-110.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-111.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-112.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-113.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-114.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-115.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-116.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-117.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-118.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-119.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-120.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-121.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-122.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-123.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-124.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# The model filename is: TestData/KrummhornShureKSM44Right-Live10 ShureKSM44Right-101.wav
#
# This clip should be a: Krummhorn8
# The model says it is a: Krummhorn8
# ...
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-109.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-110.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-111.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-112.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-113.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-114.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-115.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-116.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-117.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-118.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8AT4051Left AT4051 WinLett-119.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-461.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-462.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-463.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-464.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-465.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-466.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-467.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-468.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-469.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-470.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-471.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-472.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-473.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-474.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-475.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-476.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-477.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-478.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksLeft Earthworks, WinLEft-479.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-101.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-102.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-103.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-104.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-105.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-106.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-107.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-108.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-109.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-110.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-111.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-112.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-113.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-114.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-115.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-116.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-117.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-118.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8EarthworksRight Earthworks, WinRight-119.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-101.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-102.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-103.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-104.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-105.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-106.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-107.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-108.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-109.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-110.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-111.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-112.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-113.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-114.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-115.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-116.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-117.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-118.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8Octava Octava-119.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-101.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-102.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-103.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-104.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-105.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-106.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-107.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-108.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-109.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-110.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-111.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-112.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-113.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-114.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-115.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-116.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-117.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-118.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Left Shure KSM44 WinLeft-119.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-101.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-102.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-103.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-104.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-105.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-106.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-107.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-108.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-109.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-110.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-111.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-112.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-113.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-114.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-115.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Trumpette8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-116.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-117.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-118.wav
#
# This clip should be a: Trumpette8
# The model says it is a: Krummhorn8
# The model filename is: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-119.wav

# %%
print("There were " + str(len(mislabeledSamples)) + " mislabled samples:")
for i in range(0, len(mislabeledSamples)):
  wgInd = mislabeledSamples[i][0]
  data, label = testData.__getitem__(wgInd)
  print("i: " + str(i))
  print("The model predicted a: " + str(testDataI2C[mislabeledSamples[i][1]]))
  print("The correct label was: " + str(testDataI2C[label]))
  print("The filename was: " + str(testData.__getFileName__(wgInd)))
  IPython.display.display(IPython.display.Audio(filename= testData.__getFileName__(wgInd)))
  print("")
# Out:
# There were 9 mislabled samples:
# i: 0
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-101.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 1
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-102.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 2
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-106.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 3
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-108.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 4
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-110.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 5
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-113.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 6
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-117.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 7
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-118.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# i: 8
# The model predicted a: Krummhorn8
# The correct label was: Trumpette8
# The filename was: TestData/Trumpette8ShureKSM44Right ShureKSM44 WinRight-119.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filenameTest = os.getcwd() + "/TestData/Krummhorn8ShureKSM44Left-Live10 ShureKSM44Left-103.wav"
print(os.getcwd())
spec = spec_to_image(get_melspectrogram_db(filenameTest))
spec_t = torch.tensor(spec).to(device, dtype = torch.float32)
pr = trained_model(spec_t.reshape(1,1,*spec_t.shape))
ind = pr.argmax(dim=1).cpu().detach().numpy().ravel()[0]
print("ind: " + str(ind))
print("This is testDataI2C: " + str(testDataI2C))
print(testDataI2C[ind])
IPython.display.display(IPython.display.Audio(filename= filenameTest))
# Out:
# /content/drive/My Drive/OrganStopDataset
# ind: 1
# This is testDataI2C: {0: 'Hautbois', 1: 'Krummhorn8', 2: 'Principal8', 3: 'Trumpette8'}
# Krummhorn8
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
openTestF.close()
testDataF.close()
